# %%
from langchain_core.messages import HumanMessage
from langchain_openai import ChatOpenAI
import os
from dotenv import load_dotenv
load_dotenv(dotenv_path=".env")
os.environ['OPENAI_API_KEY'] = os.getenv("OPENAI_API_KEY")
model = ChatOpenAI(model="gpt-4o")

# %%
import base64

with open('output.png', 'rb') as file:
    # Read the binary content of the file
    file_content = file.read()

# Encode the binary content to Base64
image_data = base64.b64encode(file_content).decode("utf-8")
image_data
# Out:
# '...'

# %%
message = HumanMessage(
    content=[
        {"type": "text", "text": "Midjourney prompt for this image"},
        {
            "type": "image_url",
            "image_url": {"url": f"data:image/jpeg;base64,{image_data}"},
        },
    ],
)
response = model.invoke([message])
print(response.content)
# Out:
# Sure! Here's a Midjourney prompt inspired by the image:
#
# "Create a futuristic portrait of a confident man wearing black sunglasses and a thick silver chain. He is dressed in a black turtleneck, standing in a high-tech environment with intricate geometric patterns and soft, ambient lighting. The atmosphere should convey a sense of modernity and style, with a focus on the interplay of light and shadows."
